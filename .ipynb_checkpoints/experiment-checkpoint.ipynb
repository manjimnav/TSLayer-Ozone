# %%
from src.experiment import ExperimentLauncher
# Out:
# 2023-05-15 11:57:43.919630: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-15 11:57:44.029164: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-05-15 11:57:44.430422: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvrtc.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-15 11:57:44.430464: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-15 11:57:44.430468: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
config_path = 'configuration/Ozone/'
experiment_launcher = ExperimentLauncher(config_path, save_file='results/Ozone/results_ubuntu.csv')

# %%
experiment_launcher.run()
# Out:
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lstm', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'lasso', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.5}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.5}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.55}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.55}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6000000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6000000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6500000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6500000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7000000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7000000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7500000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7500000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8000000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8000000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8500000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8500000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9000000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9000000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9500000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9500000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.5}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.5}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.55}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.55}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6000000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6000000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6500000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6500000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7000000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7000000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7500000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7500000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8000000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8000000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8500000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8500000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9000000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9000000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9500000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9500000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.5}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.5}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.55}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.55}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6000000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6000000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6500000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6500000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7000000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7000000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7500000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7500000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8000000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8000000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8500000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8500000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9000000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9000000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9500000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9500000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.5}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.5}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.55}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.55}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6000000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6000000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6500000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6500000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7000000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7000000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7500000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.7500000000000002}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8000000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8000000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8500000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.8500000000000003}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9000000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9000000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9500000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.9500000000000004}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.5}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.5}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.55}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.55}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6000000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6000000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 48, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'Linear', 'params': {'threshold': 0.6500000000000001}}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# ...
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.005}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.01}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.01}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 1e-05}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 1e-05}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 5e-05}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 5e-05}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.0001}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.0001}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.0005}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.0005}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.001}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.001}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.005}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.005}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.01}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.01}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 1e-05}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 1e-05}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 5e-05}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 5e-05}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.0001}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.0001}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.0005}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.0005}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.001}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.001}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.005}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.005}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.01}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'torneo', 'params': {'seq_len': 72, 'pred_len': 24, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'TimeSelectionLayer', 'params': {'regularization': 0.01}}, 'model': {'name': 'cnn', 'params': {'keep_dims': True, 'type': 'tensorflow'}}}
#       mean_squared_error  mean_absolute_error  mean_absolute_percentage_error  \
# 0             472.991363            17.249499                    5.997604e-01
# 1             703.856786            20.653627                    9.329855e-01
# 2            1079.178489            26.037353                    1.187631e+00
# 3             435.996226            17.676823                    6.849203e-01
# 4             664.125630            21.000440                    9.845222e-01
# ...                  ...                  ...                             ...
# 2083          628.966214            19.859746                    1.320189e+13
# 2084          599.760301            18.734097                    1.249398e+13
# 2085          607.073795            19.155201                    9.632245e+12
# 2086          682.799932            20.308333                    1.012685e+13
# 2087          833.665200            22.181173                    1.294594e+13
#
#             r2        dataset   dataset_name  dataset_params_seq_len  \
# 0     0.166811  rondadelvalle  rondadelvalle                      24
# 1     0.084358  rondadelvalle  rondadelvalle                      24
# 2    -0.280327  rondadelvalle  rondadelvalle                      24
# 3     0.231851  rondadelvalle  rondadelvalle                      48
# 4     0.111585  rondadelvalle  rondadelvalle                      48
# ...        ...            ...            ...                     ...
# 2083 -0.364488         torneo         torneo                      72
# 2084 -0.200065         torneo         torneo                      72
# 2085 -0.227001         torneo         torneo                      72
# 2086 -0.358702         torneo         torneo                      72
# 2087 -0.539337         torneo         torneo                      72
#
#       dataset_params_pred_len  dataset_params_shift  \
# 0                           1                    24
# 1                           8                    24
# 2                          24                    24
# 3                           1                    24
# 4                           8                    24
# ...                       ...                   ...
# 2083                       24                    24
# 2084                       24                    24
# 2085                       24                    24
# 2086                       24                    24
# 2087                       24                    24
#
#       dataset_params_select_timesteps  ... model_name  model_params_keep_dims  \
# 0                                True  ...      dense                   False
# 1                                True  ...      dense                   False
# 2                                True  ...      dense                   False
# 3                                True  ...      dense                   False
# 4                                True  ...      dense                   False
# ...                               ...  ...        ...                     ...
# 2083                             True  ...        cnn                    True
# 2084                             True  ...        cnn                    True
# 2085                             True  ...        cnn                    True
# 2086                             True  ...        cnn                    True
# 2087                             True  ...        cnn                    True
#
#      model_params_type                                           features  \
# 0           tensorflow  ['dd t-24', 'no2 t-24', 'tmp t-24', 'pm10 t-24...
# 1           tensorflow  ['dd t-24', 'no2 t-24', 'tmp t-24', 'pm10 t-24...
# 2           tensorflow  ['dd t-24', 'no2 t-24', 'tmp t-24', 'pm10 t-24...
# 3           tensorflow  ['dd t-48', 'no2 t-48', 'tmp t-48', 'pm10 t-48...
# 4           tensorflow  ['dd t-48', 'no2 t-48', 'tmp t-48', 'pm10 t-48...
# ...                ...                                                ...
# 2083        tensorflow  ['vv t-72', 'pm10 t-72', 'dd t-72', 'tmp t-72'...
# 2084        tensorflow  ['vv t-72', 'pm10 t-72', 'dd t-72', 'tmp t-72'...
# 2085        tensorflow  ['vv t-72', 'pm10 t-72', 'dd t-72', 'tmp t-72'...
# 2086        tensorflow  ['vv t-72', 'pm10 t-72', 'dd t-72', 'tmp t-72'...
# 2087        tensorflow  ['vv t-72', 'pm10 t-72', 'dd t-72', 'tmp t-72'...
#
#                                       selected_features    duration  \
# 0     ['dd t-24', 'no2 t-24', 'tmp t-24', 'pm10 t-24...  101.012412
# 1     ['dd t-24', 'no2 t-24', 'tmp t-24', 'pm10 t-24...  123.506246
# 2     ['dd t-24', 'no2 t-24', 'tmp t-24', 'pm10 t-24...  140.159406
# 3     ['dd t-48', 'no2 t-48', 'tmp t-48', 'pm10 t-48...   75.552598
# 4     ['dd t-48', 'no2 t-48', 'tmp t-48', 'pm10 t-48...  122.191391
# ...                                                 ...         ...
# 2083  ['dd t-71', 'target_o3 t-71', 'vv t-69', 'dd t...  116.219496
# 2084  ['target_o3 t-61', 'target_o3 t-55', 'vv t-53'...  132.339088
# 2085  ['target_o3 t-71', 'target_o3 t-60', 'vv t-53'...  145.986254
# 2086  ['target_o3 t-52', 'target_o3 t-22', 'target_o...  160.492578
# 2087  ['target_o3 t-52', 'target_o3 t-22', 'target_o...  149.542214
#
#                                                 history  \
# 0     [0.44244110584259033, 0.6702210307121277, 0.62...
# 1     [0.9869356751441956, 0.9024670124053955, 0.853...
# 2     [0.8851418495178223, 0.8005710244178772, 0.746...
# 3     [2.411708116531372, 1.3341566324234009, 0.6927...
# 4     [0.8340575695037842, 0.8934583067893982, 0.738...
# ...                                                 ...
# 2083  [1.2636405229568481, 1.1098995208740234, 1.039...
# 2084  [1.2541618347167969, 1.1434139013290405, 1.106...
# 2085  [1.3101173639297485, 1.235612154006958, 1.1609...
# 2086  [1.2791804075241089, 1.3026024103164673, 1.339...
# 2087  [1.2900604009628296, 1.3418539762496948, 1.336...
#
#                                   code selection_params_threshold  \
# 0     1b62dede3d982a0eecdfd3bd045c4277                        NaN
# 1     a6fa86e477a9414cc79bbc6953c333fd                        NaN
# 2     1043874fd600fe6982f1a141a5055c5b                        NaN
# 3     70e86c7ecf2e3a0ee2350eba86234cbe                        NaN
# 4     9778b775c9cfb9ccb6225fdad3d13cd2                        NaN
# ...                                ...                        ...
# 2083  65f6fa619aabafa186b44ab6b8720e5f                        NaN
# 2084  3423a6e92bd1d15491f36d3c54c177b9                        NaN
# 2085  6e509371c9247cbaff97dc5f44a0db85                        NaN
# 2086  98840ebe514087141e68212ad7a59a8b                        NaN
# 2087  4fbdace1fb6ceb54e0cfee0ca7867e13                        NaN
#
#      selection_params_regularization
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 2083                          0.0001
# 2084                          0.0005
# 2085                          0.0010
# 2086                          0.0050
# 2087                          0.0100
#
# [2088 rows x 22 columns]
