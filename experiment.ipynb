# %%
from src.experiment import ExperimentLauncher
# Out:
# 2023-05-08 20:42:38.999696: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-08 20:42:39.106890: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-05-08 20:42:39.469000: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvrtc.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-08 20:42:39.469043: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-08 20:42:39.469048: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
config_path = 'configuration/Ozone/'
experiment_launcher = ExperimentLauncher(config_path, save_file='results/Ozone/results_ubuntu.csv')

# %%
experiment_launcher.run()
# Out:
#    mean_squared_error  mean_absolute_error  mean_absolute_percentage_error  \
# 0          472.991363            17.249499                        0.599760
# 0          703.856786            20.653627                        0.932985
# 0         1079.178489            26.037353                        1.187631
# 0          435.996226            17.676823                        0.684920
# 0          664.125630            21.000440                        0.984522
# 0          994.213236            25.410583                        1.357235
# 0          401.482594            15.895770                        0.646521
# 0          810.675269            22.754838                        1.001286
# 0         1007.814021            25.567745                        1.613393
# 0          237.338144            12.253778                        0.504847
# 0          496.629078            17.700991                        0.810609
# 0          755.806529            22.188743                        1.067207
# 0         3448.243006            46.649805                        2.234003
# 0          501.401327            17.663405                        0.773452
# 0          774.399242            22.453853                        1.054268
# 0           84.154278             6.936152                        0.207050
# 0          522.447587            18.059265                        0.827496
# 0          816.515343            23.034325                        1.043010
# 0          136.526433             9.293410                        0.320890
# 0          522.051537            17.769421                        0.686950
# 0          734.880216            22.026330                        1.188095
# 0           88.542135             7.175903                        0.188765
# 0          534.079811            17.823467                        0.639081
# 0          747.220621            22.176219                        1.184648
# 0           95.155136             7.569552                        0.214725
# 0         3071.172744            43.572012                        2.890249
# 0          761.491841            22.320487                        1.120815
#
#          r2        dataset   dataset_name  dataset_params_seq_len  \
# 0  0.166811  rondadelvalle  rondadelvalle                      24
# 0  0.084358  rondadelvalle  rondadelvalle                      24
# 0 -0.280327  rondadelvalle  rondadelvalle                      24
# 0  0.231851  rondadelvalle  rondadelvalle                      48
# 0  0.111585  rondadelvalle  rondadelvalle                      48
# 0 -0.085117  rondadelvalle  rondadelvalle                      48
# 0  0.292399  rondadelvalle  rondadelvalle                      72
# 0 -0.052070  rondadelvalle  rondadelvalle                      72
# 0 -0.151816  rondadelvalle  rondadelvalle                      72
# 0  0.581922  rondadelvalle  rondadelvalle                      24
# 0  0.343763  rondadelvalle  rondadelvalle                      24
# 0  0.132438  rondadelvalle  rondadelvalle                      24
# 0 -5.075197  rondadelvalle  rondadelvalle                      48
# 0  0.344002  rondadelvalle  rondadelvalle                      48
# 0  0.105755  rondadelvalle  rondadelvalle                      48
# 0  0.851681  rondadelvalle  rondadelvalle                      72
# 0  0.316212  rondadelvalle  rondadelvalle                      72
# 0  0.055402  rondadelvalle  rondadelvalle                      72
# 0  0.759505  rondadelvalle  rondadelvalle                      24
# 0  0.328375  rondadelvalle  rondadelvalle                      24
# 0  0.157310  rondadelvalle  rondadelvalle                      24
# 0  0.844004  rondadelvalle  rondadelvalle                      48
# 0  0.318230  rondadelvalle  rondadelvalle                      48
# 0  0.133406  rondadelvalle  rondadelvalle                      48
# 0  0.832292  rondadelvalle  rondadelvalle                      72
# 0 -3.262687  rondadelvalle  rondadelvalle                      72
# 0  0.108664  rondadelvalle  rondadelvalle                      72
#
#    dataset_params_pred_len  dataset_params_shift  \
# 0                        1                    24
# 0                        8                    24
# 0                       24                    24
# 0                        1                    24
# 0                        8                    24
# 0                       24                    24
# 0                        1                    24
# 0                        8                    24
# 0                       24                    24
# 0                        1                    24
# 0                        8                    24
# 0                       24                    24
# 0                        1                    24
# 0                        8                    24
# 0                       24                    24
# 0                        1                    24
# 0                        8                    24
# 0                       24                    24
# 0                        1                    24
# 0                        8                    24
# 0                       24                    24
# 0                        1                    24
# 0                        8                    24
# 0                       24                    24
# 0                        1                    24
# 0                        8                    24
# 0                       24                    24
#
#    dataset_params_select_timesteps selection_name selection_params model_name  \
# 0                             True    NoSelection             None      dense
# 0                             True    NoSelection             None      dense
# 0                             True    NoSelection             None      dense
# 0                             True    NoSelection             None      dense
# 0                             True    NoSelection             None      dense
# 0                             True    NoSelection             None      dense
# 0                             True    NoSelection             None      dense
# 0                             True    NoSelection             None      dense
# 0                             True    NoSelection             None      dense
# 0                             True    NoSelection             None       lstm
# 0                             True    NoSelection             None       lstm
# 0                             True    NoSelection             None       lstm
# 0                             True    NoSelection             None       lstm
# 0                             True    NoSelection             None       lstm
# 0                             True    NoSelection             None       lstm
# 0                             True    NoSelection             None       lstm
# 0                             True    NoSelection             None       lstm
# 0                             True    NoSelection             None       lstm
# 0                             True    NoSelection             None        cnn
# 0                             True    NoSelection             None        cnn
# 0                             True    NoSelection             None        cnn
# 0                             True    NoSelection             None        cnn
# 0                             True    NoSelection             None        cnn
# 0                             True    NoSelection             None        cnn
# 0                             True    NoSelection             None        cnn
# 0                             True    NoSelection             None        cnn
# 0                             True    NoSelection             None        cnn
#
#    model_params_keep_dims model_params_type  \
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
# 0                    True        tensorflow
#
#                                             features  \
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...
#
#                                    selected_features     duration  \
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...   101.012412
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...   123.506246
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...   140.159406
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...    75.552598
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...   122.191391
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...   118.755404
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...    76.011418
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...    89.543363
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...   109.412972
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...  1559.019340
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...  1583.205125
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...  1498.684401
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...  2880.274034
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...  2992.378850
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...  2939.392625
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...  3635.394875
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...  3580.869723
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...  3609.088774
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...   155.479630
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...   193.028888
# 0  [dd t-24, no2 t-24, tmp t-24, pm10 t-24, vv t-...   189.857707
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...   155.446246
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...   205.932696
# 0  [dd t-48, no2 t-48, tmp t-48, pm10 t-48, vv t-...   177.709290
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...   181.053511
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...   210.933931
# 0  [dd t-72, no2 t-72, tmp t-72, pm10 t-72, vv t-...   154.927565
#
#                                              history  \
# 0  [0.44244110584259033, 0.6702210307121277, 0.62...
# 0  [0.9869356751441956, 0.9024670124053955, 0.853...
# 0  [0.8851418495178223, 0.8005710244178772, 0.746...
# 0  [2.411708116531372, 1.3341566324234009, 0.6927...
# 0  [0.8340575695037842, 0.8934583067893982, 0.738...
# 0  [0.8395912647247314, 0.7301843762397766, 0.691...
# 0  [3.124025583267212, 2.605163335800171, 0.36563...
# 0  [0.7631351947784424, 0.8372728228569031, 0.715...
# 0  [0.8022048473358154, 0.6704564690589905, 0.559...
# 0  [0.6822423338890076, 0.6282588839530945, 0.583...
# 0  [1.3006263971328735, 1.2602204084396362, 1.129...
# 0  [0.9046302437782288, 0.8994404673576355, 0.864...
# 0  [0.8596210479736328, 0.8407884240150452, 0.801...
# 0  [1.2899917364120483, 1.248620867729187, 1.1515...
# 0  [0.9051356315612793, 0.9137710928916931, 0.895...
# 0  [0.9648337364196777, 1.0325044393539429, 1.122...
# 0  [1.2327747344970703, 1.1805962324142456, 1.129...
# 0  [0.9015006422996521, 0.9126002788543701, 0.902...
# 0  [0.7348734736442566, 0.6655314564704895, 0.649...
# 0  [1.3867506980895996, 1.385696530342102, 1.3969...
# 0  [1.0138709545135498, 0.9187991619110107, 0.837...
# 0  [1.0349715948104858, 1.0752729177474976, 1.122...
# 0  [1.3232403993606567, 1.3456965684890747, 1.383...
# 0  [0.9814868569374084, 0.9067315459251404, 0.830...
# 0  [0.9826828837394714, 1.0198506116867065, 1.067...
# 0  [1.3025927543640137, 1.2770072221755981, 1.142...
# 0  [0.9737761616706848, 0.9089636206626892, 0.830...
#
#                                code
# 0  1b62dede3d982a0eecdfd3bd045c4277
# 0  a6fa86e477a9414cc79bbc6953c333fd
# 0  1043874fd600fe6982f1a141a5055c5b
# 0  70e86c7ecf2e3a0ee2350eba86234cbe
# 0  9778b775c9cfb9ccb6225fdad3d13cd2
# 0  d8eb75cd2278565e9bfd2b4a8619a9c8
# 0  fe774a9cab7a225f6bf4453300d5e521
# 0  cca7667071b73a18b7d832ffd969c480
# 0  a234dd95622d54f786faf77f2b74da8c
# 0  3a6a00fa68d3544b05641a9a8d4f4fae
# 0  ffcabf2ddbc84a048c894c973560dc6e
# 0  e15f45f7df345228898a2809ef1bc1ba
# 0  4c64ba78476057685ef7e8e55df59594
# 0  a050941df65a8ad05f90a030ba7ec582
# 0  f190ddfb7b184cc4ab0aee068dfe7087
# 0  1f1be7832eb73ec027011da589583eae
# 0  ec61af6f23737954ab3bc510e4de7707
# 0  3d2f83ae013ca195b499ca048921461a
# 0  e3aa97dca0584b231cf1b8a9a5e7b01a
# 0  a33df7084143123e8dfaa79603c7d6ae
# 0  88b68ce471e012ccdaf441d118c7ad69
# 0  2a28376273ef3098c077fab03c7ff143
# 0  02369d3957db1455eec0e41183086008
# 0  50139d32ed4cb31b3dabdd471069615f
# 0  2126d0fd3e3b25bcdc09e89024fbe9b6
# 0  2fd94a6707a975168aef412bd63e2b97
# 0  c63cdcea923dae8b9761ef7ff2f74be1
# {'dataset': {'name': 'rondadelvalle', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'decisiontree', 'params': {'keep_dims': False, 'type': 'sklearn'}}}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 experiment_launcher.run()
#
# File ~/Documents/TSLayer-Ozone/src/experiment.py:231, in ExperimentLauncher.run(self)
#     228     print(f"Skipping {params}")
#     229     continue
# --> 231 metrics = experiment.run()
#     233 self.metrics = pd.concat([self.metrics, metrics])
#     235 self.metrics.to_csv(self.save_file, index=None)
#
# File ~/Documents/TSLayer-Ozone/src/experiment.py:163, in ExperimentInstance.run(self)
#     160 model, history = self.train(model, data_train, data_valid)
#     161 duration = time.time() - start
# --> 163 self.metrics = self.calculate_metrics(model, history, data_test, duration)
#     165 return self.metrics
#
# File ~/Documents/TSLayer-Ozone/src/experiment.py:148, in ExperimentInstance.calculate_metrics(self, model, history, data_test, duration)
#     144 metrics['selected_features'] = [original_features[self.selected_idxs].tolist()]
#     146 metrics['duration'] = duration
# --> 148 metrics['history'] = str(history.history.get('val_loss', None))
#     150 metrics['code'] = self.code
#     152 return metrics
#
# AttributeError: 'NoneType' object has no attribute 'history'
