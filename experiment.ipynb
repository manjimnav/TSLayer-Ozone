# %%
from src.experiment import ExperimentLauncher

# %%
config_path = 'configuration/OzoneCrossval/'
experiment_launcher = ExperimentLauncher(config_path, save_file='results/OzoneCrossVal/results_final.csv', search_type='bayesian', iterations=25)
experiment_launcher.run()
# Out:
# /home/manuelj/miniconda3/envs/tf/lib/python3.8/site-packages/IPython/lib/pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# /home/manuelj/miniconda3/envs/tf/lib/python3.8/site-packages/IPython/core/formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#     mean_squared_error  root_mean_squared_error  mean_absolute_error  \
# 0           360.305137                18.981705            14.946701
# 0           318.759783                17.853845            14.183470
# 0           290.860823                17.054642            13.463186
# 0           301.917760                17.375781            13.762736
# ...
