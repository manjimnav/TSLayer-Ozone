# %%
from src.experiment import ExperimentLauncher

# %%
config_path = 'configuration/Ozone/'
experiment_launcher = ExperimentLauncher(config_path, save_file='results/Ozone/test.csv')

# %%
experiment_launcher.run()
# Out:
# {'dataset': {'name': 'aljarafe', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# Skipping {'dataset': {'name': 'aljarafe', 'params': {'seq_len': 24, 'pred_len': 1, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# {'dataset': {'name': 'aljarafe', 'params': {'seq_len': 24, 'pred_len': 8, 'shift': 24, 'select_timesteps': True}}, 'selection': {'name': 'NoSelection', 'params': None}, 'model': {'name': 'dense', 'params': {'keep_dims': False, 'type': 'tensorflow'}}}
# ...
